# %%
#se precisar  instalar
#!pip install pandas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ttt = pd.read_csv('teste.csv', delimiter=';', decimal=',')

# %%
ttt.loc[ttt.CHURN==0,'ID_IDADE1']= ttt.ID_IDADE + 20
ttt.loc[ttt.CHURN==1,'ID_IDADE1']= ttt.ID_IDADE
ttt.loc[ttt.CHURN==0,'VR_PLANO1']= ttt.VR_PLANO
ttt.loc[ttt.CHURN==1,'VR_PLANO1']= ttt.VR_PLANO + 2000
ttt.loc[ttt.CHURN==0,'Multa_Semestre1']= ttt.Multa_Semestre
ttt.loc[ttt.CHURN==1,'Multa_Semestre1']= ttt.Multa_Semestre +5

# %%
ttt.ID_IDADE1.count()
# Out:
# 4000

# %%
ttt.VR_PLANO.mean()
# Out:
# 1018.7767476822852

# %%
print(ttt.VR_PLANO.median())
# Out:
# 691.9

# %%
ttt.describe()
# Out:
#         Unnamed: 0  ID_SISTEMA_ORIGEM   ID_CONTRATO     ID_PESSOA  \
# count  4000.000000        4000.000000  4.000000e+03  4.000000e+03
# mean   1999.500000           1.954500  1.921123e+06  2.575893e+06
# std    1154.844867           3.179301  1.492078e+06  9.600552e+05
# min       0.000000           1.000000  1.260000e+02 -1.000000e+00
# 25%     999.750000           1.000000  4.782158e+05  1.859056e+06
# 50%    1999.500000           1.000000  1.255080e+06  2.606005e+06
# 75%    2999.250000           1.000000  3.365815e+06  3.332700e+06
# max    3999.000000          14.000000  4.159981e+06  4.116191e+06
#
#        ID_OPERADORA  ID_ENTIDADE  ID_TIPO_PLANO_PRINCIPAL  \
# count   4000.000000  4000.000000              4000.000000
# mean     117.573500  1648.726500                30.102250
# std      166.260661   255.285352                29.765623
# min        1.000000  1275.000000                 1.000000
# 25%       11.000000  1335.000000                 1.000000
# ...

# %%
colunas = ttt.columns

# %%
colunas
# Out:
# Index(['Unnamed: 0', 'DT_ANALISE', 'ID_SISTEMA_ORIGEM', 'ID_CONTRATO',
#        'ID_PESSOA', 'ID_OPERADORA', 'ID_ENTIDADE', 'ID_TIPO_PLANO_PRINCIPAL',
#        'ID_TIPO_CANCELAMENTO', 'ID_GEOGRAFIA',
#        ...
#        'Juros?', 'Multa_Semestre', 'Multa_Ano', 'Atraso_Decay_30',
#        'Atraso_Decay_90', 'Atraso_Decay_180', 'QT_COPARTICIPACAO', 'ID_IDADE1',
#        'VR_PLANO1', 'Multa_Semestre1'],
#       dtype='object', length=259)

# %%
colunas[-2]
# Out:
# 'VR_PLANO1'

# %%
colunas[2:4]
# Out:
# Index(['ID_SISTEMA_ORIGEM', 'ID_CONTRATO'], dtype='object')

# %%
x = [2,4]
colunas[x]
# Out:
# Index(['ID_SISTEMA_ORIGEM', 'ID_PESSOA'], dtype='object')

# %%
for k in colunas:
  print(k)
# Out:
# Unnamed: 0
# DT_ANALISE
# ID_SISTEMA_ORIGEM
# ID_CONTRATO
# ID_PESSOA
# ID_OPERADORA
# ID_ENTIDADE
# ID_TIPO_PLANO_PRINCIPAL
# ID_TIPO_CANCELAMENTO
# ID_GEOGRAFIA
# ID_GEOGRAFIA_ENTIDADE
# ID_SITUACAO_CONTRATO
# ID_CLASS_CLIENTE
# ID_RISCO_CONTRATO
# ID_STATUS
# ID_GRAU_PARENTESCO
# ID_TEMPO_PERMANENCIA
# ID_JANELA_PAGTO
# ID_PRODUTO
# ID_SEGMENTACAO
# ID_FAIXA_ETARIA_ANS
# ID_IDADE
# ID_FAIXA_VALOR_CONTRATO
# ID_FAIXA_VALOR_VIDA
# FL_EXCLIENTE
# FL_RETORNADO_IMEDIATO
# FL_RETORNADO_POSTERIOR
# DT_INICIO
# DT_FIM
# QT_PLANO_ADICIONAL
# QT_COBRANCAS_AVENCER
# QT_COBRANCAS_VENCIDA
# QT_LIMINAR
# FL_UPGRADE_PLANO
# FL_DOWNGRADE_PLANO
# VR_PLANO
# VR_REPASSE
# DT_PROCESSAMENTO
# QT_MESES_PERMANENCIA
# QT_DIAS_PERMANENCIA
# ID_BENEFICIARIO
# ID_PRODUTOR
# ID_CANAL_VENDA
# CD_CONTRATO
# CD_PESSOA
# NU_MATRICULA
# CD_BENEFICIARIO
# CD_PRODUTOR
# FL_COPART
# CHURN
# PRÉ-CHURN
# CHURN_ATUAL
# PLANOS_P_PESSOA
# VR_PLANO_CLIENTE
# VR_REPASSE_CLIENTE
# VR_PLANO_CONTRATO
# VR_REPASSE_CONTRATO
# ...

# %%
df = ttt[['ID_IDADE1','VR_PLANO1','CHURN','DS_SEXO','SERASA','TENURE','IDHM Score','Multa_Semestre1']]

# %%
df
# Out:
#       ID_IDADE1  VR_PLANO1  CHURN DS_SEXO  SERASA  TENURE  IDHM Score  \
# 0          60.0      698.1      0       F       0  1205.0    0.866143
# 1          48.0      203.5      0       F       0   701.0    0.777956
# 2          69.0      968.7      0       F       0   871.0    0.717271
# 3          46.0      786.6      0       F       0  1236.0    0.840583
# 4          56.0     1019.7      0       M       0  4372.0    0.872389
# ...         ...        ...    ...     ...     ...     ...         ...
# 3995       44.0     3077.7      1       F       0  1704.0    0.756137
# 3996       17.0     2323.5      1       F       0    91.0    0.878011
# 3997       57.0     3485.0      1       X      -1  2920.0    0.822528
# 3998       40.0     3596.7      1       F       0   577.0    0.840583
# 3999       41.0     2759.2      1       F       0  4048.0         NaN
#
#       Multa_Semestre1
# 0                 3.0
# 1                 1.0
# 2                 1.0
# 3                 0.0
# ...

# %%
df.DS_SEXO.value_counts()
# Out:
# F    2338
# M    1504
# X     158
# Name: DS_SEXO, dtype: int64

# %%
df.CHURN.value_counts()
# Out:
# 0    2000
# 1    2000
# Name: CHURN, dtype: int64

# %%
df.SERASA.value_counts()
# Out:
#  0    3648
# -1     258
#  1      94
# Name: SERASA, dtype: int64

# %%
df[df.CHURN == 0].SERASA.value_counts()
# Out:
#  0    1852
# -1     147
#  1       1
# Name: SERASA, dtype: int64

# %%
df[df.CHURN == 1].SERASA.value_counts()
# Out:
#  0    1796
# -1     111
#  1      93
# Name: SERASA, dtype: int64

# %%
df[df.CHURN == 0].DS_SEXO.value_counts()
# Out:
# F    1147
# M     781
# X      72
# Name: DS_SEXO, dtype: int64

# %%
df[df.CHURN == 1].DS_SEXO.value_counts()
# Out:
# F    1191
# M     723
# X      86
# Name: DS_SEXO, dtype: int64

# %%
df.isna().sum()
# Out:
# ID_IDADE1             0
# VR_PLANO1             9
# CHURN                 0
# DS_SEXO               0
# SERASA                0
# TENURE               18
# IDHM Score          275
# Multa_Semestre1    1147
# dtype: int64

# %%
df.fillna(0,inplace=True)
# Out:
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:4462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
df.isna().sum()
# Out:
# ID_IDADE1          0
# VR_PLANO1          0
# CHURN              0
# DS_SEXO            0
# SERASA             0
# TENURE             0
# IDHM Score         0
# Multa_Semestre1    0
# dtype: int64

# %%
df.dropna(inplace=True)
# Out:
# <ipython-input-79-c64f9f573c18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# ID_IDADE1          0
# VR_PLANO1          0
# CHURN              0
# DS_SEXO            0
# SERASA             0
# TENURE             0
# IDHM Score         0
# Multa_Semestre1    0
# dtype: int64

# %%
df
# Out:
#       ID_IDADE1  VR_PLANO1  CHURN DS_SEXO  SERASA  TENURE  IDHM Score  \
# 0          60.0      698.1      0       F       0  1205.0    0.866143
# 1          48.0      203.5      0       F       0   701.0    0.777956
# 2          69.0      968.7      0       F       0   871.0    0.717271
# 3          46.0      786.6      0       F       0  1236.0    0.840583
# 4          56.0     1019.7      0       M       0  4372.0    0.872389
# ...         ...        ...    ...     ...     ...     ...         ...
# 3995       44.0     3077.7      1       F       0  1704.0    0.756137
# 3996       17.0     2323.5      1       F       0    91.0    0.878011
# 3997       57.0     3485.0      1       X      -1  2920.0    0.822528
# 3998       40.0     3596.7      1       F       0   577.0    0.840583
# 3999       41.0     2759.2      1       F       0  4048.0    0.000000
#
#       Multa_Semestre1
# 0                 3.0
# 1                 1.0
# 2                 1.0
# 3                 0.0
# ...

# %%
df.describe()
# Out:
#         ID_IDADE1     VR_PLANO1        CHURN       SERASA       TENURE  \
# count  4000.00000   4000.000000  4000.000000  4000.000000  4000.000000
# mean     48.14200   2012.484500     0.500000    -0.041000  1072.148750
# std      21.38563   1499.841114     0.500063     0.293838  1160.745032
# min       1.00000      0.000000     0.000000    -1.000000     0.000000
# 25%      33.00000    634.700000     0.000000     0.000000   272.000000
# 50%      47.00000   2213.800000     0.500000     0.000000   669.000000
# 75%      62.00000   2822.775000     1.000000     0.000000  1429.000000
# max     120.00000  12503.900000     1.000000     1.000000  7640.000000
#
#         IDHM Score  Multa_Semestre1
# count  4000.000000       4000.00000
# mean      0.742493          2.20225
# std       0.210958          2.98531
# min       0.000000          0.00000
# 25%       0.738000          0.00000
# 50%       0.803698          0.00000
# 75%       0.848239          5.00000
# ...

# %%
df.rename(columns={'CHURN':'Target'}, inplace=True)
# Out:
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df
# Out:
#       ID_IDADE1  VR_PLANO1  Target DS_SEXO  SERASA  TENURE  IDHM Score  \
# 0          60.0      698.1       0       F       0  1205.0    0.866143
# 1          48.0      203.5       0       F       0   701.0    0.777956
# 2          69.0      968.7       0       F       0   871.0    0.717271
# 3          46.0      786.6       0       F       0  1236.0    0.840583
# 4          56.0     1019.7       0       M       0  4372.0    0.872389
# ...         ...        ...     ...     ...     ...     ...         ...
# 3995       44.0     3077.7       1       F       0  1704.0    0.756137
# 3996       17.0     2323.5       1       F       0    91.0    0.878011
# 3997       57.0     3485.0       1       X      -1  2920.0    0.822528
# 3998       40.0     3596.7       1       F       0   577.0    0.840583
# 3999       41.0     2759.2       1       F       0  4048.0    0.000000
#
#       Multa_Semestre1
# 0                 3.0
# 1                 1.0
# 2                 1.0
# ...

# %%
sns.kdeplot(df.loc[df['Target']==1].ID_IDADE1, color='b', shade=True, Label= "Análise do CHURN")
plt.xlabel('IDADE')
plt.ylabel('Probability Density')
# Out:
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:949: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   scout = self.ax.fill_between([], [], **plot_kws)
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:992: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   artist = ax.fill_between(
# Text(0, 0.5, 'Probability Density')

# %%
df[df.Target == 1].ID_IDADE1.mean()
# Out:
# 37.792

# %%
sns.kdeplot(df.loc[df['Target']==0].ID_IDADE1, color='b', shade=True, Label= "Análise do CHURN")
plt.xlabel('IDADE')
plt.ylabel('Probability Density')
plt.show()
# Out:
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:949: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   scout = self.ax.fill_between([], [], **plot_kws)
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:992: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   artist = ax.fill_between(

# %%
sns.kdeplot(df.loc[df['Target']==0].ID_IDADE1, color='b', shade=True, Label= "Análise do CHURN")
sns.kdeplot(df.loc[df['Target']==1].ID_IDADE1, color='r', shade=True, Label= "Análise do CHURN")
plt.xlabel('IDADE')
plt.ylabel('Probability Density')
plt.show()
# Out:
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:949: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   scout = self.ax.fill_between([], [], **plot_kws)
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:992: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   artist = ax.fill_between(
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:949: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   scout = self.ax.fill_between([], [], **plot_kws)
# ...

# %%
sns.kdeplot(df.ID_IDADE1, color='b', shade=True, Label= "Análise do CHURN")
plt.xlabel('IDADE')
plt.ylabel('Probability Density')
# Out:
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:949: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   scout = self.ax.fill_between([], [], **plot_kws)
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:992: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   artist = ax.fill_between(
# Text(0, 0.5, 'Probability Density')

# %%
sns.kdeplot(df.loc[df['Target']==0].VR_PLANO1, color='b', shade=True, Label= "Análise do CHURN")
sns.kdeplot(df.loc[df['Target']==1].VR_PLANO1, color='r', shade=True, Label= "Análise do CHURN")
plt.xlabel('Valor do Plano')
plt.ylabel('Probability Density')
# Out:
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:949: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   scout = self.ax.fill_between([], [], **plot_kws)
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:992: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   artist = ax.fill_between(
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:949: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   scout = self.ax.fill_between([], [], **plot_kws)
# ...

# %%
sns.kdeplot(df.loc[df['Target']==0].Multa_Semestre1, color='b', shade=True, Label= "Análise do CHURN")
sns.kdeplot(df.loc[df['Target']==1].Multa_Semestre1, color='r', shade=True, Label= "Análise do CHURN")
plt.xlabel('Multas')
plt.ylabel('Probability Density')
# Out:
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:949: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   scout = self.ax.fill_between([], [], **plot_kws)
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:992: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   artist = ax.fill_between(
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:949: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   scout = self.ax.fill_between([], [], **plot_kws)
# ...

# %%
sns.kdeplot(df.loc[df['Target']==0].Multa_Semestre1,df.loc[df['Target']==0].VR_PLANO1, color='b', 
            shade=True,Label = 'CHURN', cmap ="Blues", shade_lowest=False)
plt.show()
# Out:
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:1676: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0.05`, but please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:1182: UserWarning: The following kwargs were not used by contour: 'Label'
#   cset = contour_func(

# %%
sns.kdeplot(df.loc[df['Target']==1].Multa_Semestre1,df.loc[df['Target']==1].VR_PLANO1, color='r', 
            shade=True,Label = 'CHURN', cmap ="Reds", shade_lowest=False)
plt.show()
# Out:
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:1676: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0.05`, but please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:1182: UserWarning: The following kwargs were not used by contour: 'Label'
#   cset = contour_func(

# %%
sns.kdeplot(df.loc[df['Target']==0].Multa_Semestre1,df.loc[df['Target']==0].VR_PLANO1, color='b', 
            shade=True,Label = 'CHURN', cmap ="Blues")
sns.kdeplot(df.loc[df['Target']==1].Multa_Semestre1,df.loc[df['Target']==1].VR_PLANO1, color='r', 
            shade=True,Label = 'CHURN', cmap ="Reds")

plt.show()
# Out:
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:1182: UserWarning: The following kwargs were not used by contour: 'Label'
#   cset = contour_func(
# C:\Users\gabri\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
df.corr()
# Out:
#                  ID_IDADE1  VR_PLANO1    Target    SERASA    TENURE  \
# ID_IDADE1         1.000000   0.066309 -0.484030 -0.141218  0.378232
# VR_PLANO1         0.066309   1.000000  0.689460  0.097795  0.229141
# Target           -0.484030   0.689460  1.000000  0.108917 -0.079484
# SERASA           -0.141218   0.097795  0.108917  1.000000 -0.058941
# TENURE            0.378232   0.229141 -0.079484 -0.058941  1.000000
# IDHM Score        0.061217   0.103124  0.003486  0.065552  0.010428
# Multa_Semestre1  -0.339802   0.278401  0.480664  0.209860 -0.050852
#
#                  IDHM Score  Multa_Semestre1
# ID_IDADE1          0.061217        -0.339802
# VR_PLANO1          0.103124         0.278401
# Target             0.003486         0.480664
# SERASA             0.065552         0.209860
# TENURE             0.010428        -0.050852
# IDHM Score         1.000000         0.016373
# Multa_Semestre1    0.016373         1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>
